# %%
import pandas as pd
import json
import glob
import os
# %matplotlib inline

# %%
df=pd.read_csv('/Users/ashokdeb/Desktop/2020_pres/csv_files_2020/pres2020-2020-02-08.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.drop_duplicates(subset=['userid'],keep='first',inplace=True)

# %%
len(df)
# Out:
# 529068

# %%
df.columns
# Out:
# Index(['tweetid', 'userid', 'screen_name', 'date', 'lang', 'location', 'text',
#        'extended', 'coord', 'tweet_type', 'friends_count', 'listed_count',
#        'followers_count', 'favourites_count', 'statuses_count', 'verified',
#        'hashtag', 'profile_pic_url', 'profile_banner_url', 'display_name',
#        'date_first_tweet', 'account_creation_date', 'rt_urls_list',
#        'mentionid', 'mentionsn', 'rt_screen', 'rt_userid', 'q_screen',
#        'q_userid'],
#       dtype='object')

# %%
df.verified.value_counts()
# Out:
# False    1908856
# True        6610
# Name: verified, dtype: int64

# %%
df[(df['verified']==True) & (df['tweet_type']=='orignial')]
# Out:
#                      tweetid               userid      screen_name  \
# 399      1207086374278574081             44397959   WilkowMajority
# 4716     1207086830186827776  1062374215763066880       MIGOPChair
# 5085     1207086869487538177             40103166     micasoellner
# 5691     1207086933823721472   788264283431763969      GeenaA_WAVY
# 6680     1207087039117742080            357606935          ewarren
# 10709    1207087474591141888   938533034659168256    openletterbot
# 11197    1207087527770959872            226222147    PeteButtigieg
# 11621    1207087569453768704   938533034659168256    openletterbot
# 11769    1207087586172395520  1062374215763066880       MIGOPChair
# 14427    1207087881845538821   938533034659168256    openletterbot
# 14458    1207087886664781824   938533034659168256    openletterbot
# 14867    1207087932856778753           1206227149     repmarkpocan
# 16197    1207088085323976704            104667895   DineroEnImagen
# ...

# %%
#There are no duplicates
df.drop_duplicates(keep='first',inplace=True)
df.reset_index(drop=True,inplace=True)
len(df)

# %%
df.columns
# Out:
# Index(['tweetid', 'userid', 'screen_name', 'date', 'lang', 'location', 'text',
#        'extended', 'coord', 'tweet_type', 'friends_count', 'listed_count',
#        'followers_count', 'favourites_count', 'statuses_count', 'verified',
#        'hashtag', 'rp_screen', 'rp_userid', 'rt_screen', 'rt_userid',
#        'q_screen', 'q_userid'],
#       dtype='object')

# %%
temp=df[df['userid']==939091]
# temp=df[df['rt_userid']=='939091']
len(temp)
# Out:
# 40

# %%
temp=temp.sort_values('date')

# %%
temp.reset_index(drop=True,inplace=True)

# %%
userid_save=temp.at[0,'rt_userid']
screen_save=temp.at[0,'rt_screen']

# %%
temp['date']=pd.to_datetime(temp['date'])

# %%
temp['date']=temp['date'].map(lambda x: x.strftime('%Y-%m-%d'))

# %%
temp=temp.groupby(['date']).count()

# %%
temp['date']=temp.index

# %%
temp['rt_userid']=userid_save
temp['rt_screen']=screen_save
temp.rename(columns={'tweetid': 'retweets'},inplace=True)

# %%
temp.to_csv('files/retweet'+str(userid_save)+'.csv',index=False)

# %%
df=df[['userid','screen_name','date','followers_count']]
# df=df[['rt_userid','rt_screen','date','tweetid']]

# %%
accountid=[
'939091',
'45645232',
'15808765',
'111721601',
'226222147',
'19682187',
'476193064',
'426028646',
'26637348',
'72198806',
'30354991',
'117839957',
'21789463',
'33537967',
'33954145',
'248495200',
'342863309',
'466532637',
'216776631',
'377609596',
'357606935',
'21522338',
'2228878592',
'46764631',
'14709326'
]

# %%
for userid in accountid:
    temp=df[df['userid']==int(userid)]
#     temp=df[df['rt_userid']==userid]
    temp['date']=pd.to_datetime(temp['date'])
    temp['date']=temp['date'].map(lambda x: x.strftime('%Y-%m-%d'))
    print(len(temp))
    temp.drop_duplicates(subset=['date'],keep='first',inplace=True)
#     temp=temp.sort_values('date')
    temp.to_csv('files/follower'+str(userid)+'.csv',index=False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# ...

# %%
for userid in accountid:
    temp=df[df['rt_userid']==userid]
    temp=temp.sort_values('date')

    temp.reset_index(drop=True,inplace=True)

    userid_save=temp.at[0,'rt_userid']
    screen_save=temp.at[0,'rt_screen']

    temp['date']=pd.to_datetime(temp['date'])

    temp['date']=temp['date'].map(lambda x: x.strftime('%Y-%m-%d'))

    temp=temp.groupby(['date']).count()

    temp['date']=temp.index

    temp['rt_userid']=userid_save
    temp['rt_screen']=screen_save
    temp.rename(columns={'tweetid': 'retweets'},inplace=True)

    temp.to_csv('files/retweet'+str(userid_save)+'.csv',index=False)

# %%
os.chdir('/Users/ashokdeb/Desktop/2020_pres/files/')
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( 'follow1_all.csv', index=False, encoding='utf-8')

# %%
biden.drop_duplicates(subset=['date'],keep='first',inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
biden
# Out:
#           userid screen_name        date followers_count
# 178445    939091    JoeBiden  2019-07-11         3621996
# 220341    939091    JoeBiden  2019-07-12         3618594
# 404759    939091    JoeBiden  2019-07-13         3618867
# 537903    939091    JoeBiden  2019-07-14         3619516
# 816239    939091    JoeBiden  2019-07-15         3621063
# 1172121   939091    JoeBiden  2019-07-16         3622968
# 1402922   939091    JoeBiden  2019-07-18         3624022
# 1588748   939091    JoeBiden  2019-07-19         3625106
# 1746086   939091    JoeBiden  2019-05-21         3572974
# 2148212   939091    JoeBiden  2019-05-22         3575155
# 2290736   939091    JoeBiden  2019-05-28         3581258
# 2432810   939091    JoeBiden  2019-05-29         3581778
# 2625561   939091    JoeBiden  2019-05-31         3584760
# 3261183   939091    JoeBiden  2019-06-05         3588610
# 3398189   939091    JoeBiden  2019-06-06         3588615
# ...

# %%
df.tweet_type.value_counts()
# Out:
# retweeted_tweet_without_comment    11591585
# reply                               8601527
# quoted_tweet                        1956013
# orignial                             577146
# tweet_type                               10
# Name: tweet_type, dtype: int64

# %%
print('original =',len(df[df['tweet_type']=='orignial']))
print('reply =',len(df[df['tweet_type']=='reply']))
print('retweet =',len(df[df['tweet_type']=='retweeted_tweet_without_comment']))
print('quote =',len(df[df['tweet_type']=='quoted_tweet']))
# Out:
# original = 614885
# reply = 9117527
# retweet = 12333411
# quote = 2071146

# %%
original =len(df[df['tweet_type']=='orignial'])
reply =len(df[df['tweet_type']=='reply'])
retweet =len(df[df['tweet_type']=='retweeted_tweet_without_comment'])
quote =len(df[df['tweet_type']=='quoted_tweet'])

# %%
import matplotlib.pyplot as plt

# Pie chart
# labels = ['original\n577,146', 'reply\n8,601,527', 'retweet\n11,591,585', 'quote\n1,956,013']
labels = ['reply\n9,117,527','original\n614,885', 'retweet\n12,333,411', 'quote\n2,071,146']
# sizes = [len(df[df['tweet_type']=='orignial']), len(df[df['tweet_type']=='reply']), len(df[df['tweet_type']=='retweeted_tweet_without_comment']), len(df[df['tweet_type']=='quoted_tweet'])]
sizes = [ 9117527,614885,11591585,1956013]


# only "explode" the 2nd slice (i.e. 'Hogs')
explode = (0, 0, 0.1, 0)
#add colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=False, startangle=90, textprops={'fontsize': 16})
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
# plt.title('2020 US Presidential Tweets (follow)',size=16)
plt.tight_layout()
plt.savefig('2020_pie_follow.png', dpi=600)
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart
# labels = ['original\n577,146', 'reply\n8,601,527', 'retweet\n11,591,585', 'quote\n1,956,013']
labels = ['reply\n26,270,841','original\n1,868,638', 'retweet\n24,668,381', 'quote\n10,612,608']
# sizes = [len(df[df['tweet_type']=='orignial']), len(df[df['tweet_type']=='reply']), len(df[df['tweet_type']=='retweeted_tweet_without_comment']), len(df[df['tweet_type']=='quoted_tweet'])]
sizes = [ 26270841,1868638,24668381,10612608]


# only "explode" the 2nd slice (i.e. 'Hogs')
explode = (0, 0, 0.1, 0)
#add colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=False, startangle=90, textprops={'fontsize': 16})
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
# plt.title('2020 US Presidential Tweets (follow)',size=16)
plt.tight_layout()
plt.savefig('2020_pie_track.png', dpi=600)
plt.show()

# %%
#Use this to make pie chart

import matplotlib.pyplot as plt

# Pie chart
# labels = ['original\n577,146', 'reply\n8,601,527', 'retweet\n11,591,585', 'quote\n1,956,013']
labels = ['reply\n32,406,587','original\n2,213,963', 'retweet\n55,335,682', 'quote\n20,844,203']
# sizes = [len(df[df['tweet_type']=='orignial']), len(df[df['tweet_type']=='reply']), len(df[df['tweet_type']=='retweeted_tweet_without_comment']), len(df[df['tweet_type']=='quoted_tweet'])]
sizes = [  32406587 ,2213963,55335682,20844203]


# only "explode" the 2nd slice (i.e. 'Hogs')
explode = (0, 0, 0.1, 0)
#add colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=False, startangle=90, textprops={'fontsize': 16})
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.title('2020 US Presidential Tweets 26 Oct to 03 Jan 2020',size=16)
plt.tight_layout()
plt.savefig('2020_pie_track2.png', dpi=600)
plt.show()

# %%
#Use this to make pie chart taiwan

import matplotlib.pyplot as plt

# 
# labels = ['original\n577,146', 'reply\n8,601,527', 'retweet\n11,591,585', 'quote\n1,956,013']
labels = ['reply\n30,331','original\n31,881', 'retweet\n126,847', 'quote\n82,838']
# sizes = [len(df[df['tweet_type']=='orignial']), len(df[df['tweet_type']=='reply']), len(df[df['tweet_type']=='retweeted_tweet_without_comment']), len(df[df['tweet_type']=='quoted_tweet'])]
sizes = [  30331,31881,126847,82838]



explode = (0, 0, 0.1, 0)
#add colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=False, startangle=90, textprops={'fontsize': 16})
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')
plt.title('2020 Taiwan Presidential Election 21 Dec2019 to 4 Jan 2020',size=16)
plt.tight_layout()
plt.savefig('/Users/ashokdeb/Desktop/2020_pres/taiwan/piechart.png', dpi=600)
plt.show()

# %%
reply=reply[['screen_name','rp_screen']]

# %%
reply.to_csv('2020_follow_sample_reply_net.csv',index=False)

# %%
retweet=df[df['tweet_type']=='retweeted_tweet_without_comment']

retweet=retweet[['screen_name','rt_screen']]

retweet.to_csv('2020_follow_sample_retweet_net.csv',index=False)

# %% [markdown]
# Track tweets:

# %%
df=pd.read_csv('/Users/ashokdeb/Desktop/2020_pres/track_output_1.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,1,8,10,11,12,13,14,15,18,20,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(df)
# Out:
# 33417626

# %%
df.drop(columns=['text','hashtag'],inplace=True)

# %%
df1=pd.read_csv('/Users/ashokdeb/Desktop/2020_pres/track_output_2.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,1,8,10,11,12,13,14,15,18,20,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(df1)
# Out:
# 30002931

# %%
df1.drop(columns=['text','hashtag'],inplace=True)

# %%
33417626+30002931
# Out:
# 63420557

# %%
df1.tweet_type.value_counts()
# Out:
# reply                              12272278
# retweeted_tweet_without_comment    11778842
# quoted_tweet                        5131259
# orignial                             820468
# tweet_type                               84
# Name: tweet_type, dtype: int64

# %%
df.tweet_type.value_counts()
# Out:
# reply                              13998563
# retweeted_tweet_without_comment    12889539
# quoted_tweet                        5481349
# orignial                            1048170
# tweet_type                                5
# Name: tweet_type, dtype: int64

# %%
print(12272278+13998563)
print(11778842+12889539)
print(5131259+5481349)
print(820468+1048170)
# Out:
# 26270841
# 24668381
# 10612608
# 1868638

# %%
print(12272278+13998563+11778842+12889539+5131259+5481349+820468+1048170+614885+9117527+12333411+2071146)
# Out:
# 87557437

# %%
df.lang.value_counts()
# Out:
# en      21855259
# und      1972874
# es         74065
# in         37640
# tl         24762
# fr         20032
# ar         13032
# ja         12916
# zh         12127
# pt          9659
# sv          9490
# de          8157
# et          7979
# ht          7778
# tr          7214
# fa          6286
# pl          5810
# it          5351
# ca          4778
# da          4448
# ko          4365
# nl          4287
# hi          3958
# ro          3386
# eu          3225
# cy          2870
# no          2669
# ru          2643
# vi          1439
# fi          1173
#           ...
# is           937
# hu           841
# sl           444
# ur           423
# th           290
# iw           209
# ps           146
# uk           117
# el           111
# bn           101
# ta            91
# mr            62
# ne            47
# ckb           43
# bg            37
# ka            35
# sr            32
# kn            30
# gu            30
# am            28
# ml            26
# ...

# %% [markdown]
# URL analysis from twitter users

# %%
url_list=pd.read_csv('/Users/ashokdeb/Desktop/2020_pres/follow_rt_url.csv')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
url_list.urls.value_counts()

# %%
len(url_list)
#13.2 Million retweets with a URL which is basically every retweet
#2,918,725 didn't have URLs
#9953428 have a twitter url
# Out:
# 13178649

# %%
url_list['urls'] = url_list['urls'].map(lambda x: x[1:-1])

# %%
url_list['urls'] = url_list['urls'].map(lambda x: x.replace("'", '"'))

# %%
url_list.at[2213,'urls'].replace("'", '"')
# Out:
# '{"url": "https://t.co/GWGIro9JJp", "indices": [72, 95], "expanded_url": "https://www.politico.com/story/2019/08/19/marianne-williamson-andrew-jackson-painting-oval-office-1467789", "display_url": "politico.com/story/2019/08/…"}'

# %%
print(json.dumps(url_list.at[2213,'urls']))
# Out:
# "{'url': 'https://t.co/GWGIro9JJp', 'indices': [72, 95], 'expanded_url': 'https://www.politico.com/story/2019/08/19/marianne-williamson-andrew-jackson-painting-oval-office-1467789', 'display_url': 'politico.com/story/2019/08/\u2026'}"

# %%
my_dict = json.loads(url_list.at[2213,'urls'])
pd.DataFrame.from_dict(my_dict)
# Out:
#                     display_url  \
# 0  politico.com/story/2019/08/…
# 1  politico.com/story/2019/08/…
#
#                                         expanded_url  indices  \
# 0  https://www.politico.com/story/2019/08/19/mari...       72
# 1  https://www.politico.com/story/2019/08/19/mari...       95
#
#                        url
# 0  https://t.co/GWGIro9JJp
# 1  https://t.co/GWGIro9JJp

# %%
# url_list.dropna(how='any')
url_list = url_list[url_list.urls != ""]

# %%
len(url_list)
# Out:
# 10259924

# %%
import re

def split_num(val):
    p = re.compile("({.*)")
    return p.search(val).group(1)

# applying the function
url_list['urls'] = url_list['urls'].map(lambda x: split_num(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-f64a48928b54> in <module>()
#       6
#       7 # applying the function
# ----> 8 url_list['urls'] = url_list['urls'].map(lambda x: split_num(x))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    2311         else:
#    2312             # arg is a function
# -> 2313             new_values = map_f(values, arg)
#    2314
#    2315         return self._constructor(new_values,
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-49-f64a48928b54> in <lambda>(x)
#       6
#       7 # applying the function
# ----> 8 url_list['urls'] = url_list['urls'].map(lambda x: split_num(x))
#
# <ipython-input-49-f64a48928b54> in split_num(val)
#       3 def split_num(val):
#       4     p = re.compile("({.*)")
# ...

# %%
url_list['urls'] = url_list['urls'].map(lambda x: dict(eval(x)))
# Out:
# Traceback (most recent call last):
#
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-55-09e963f87256>", line 1, in <module>
#     url_list['urls'] = url_list['urls'].map(lambda x: dict(eval(x)))
#
#   File "/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py", line 2313, in map
#     new_values = map_f(values, arg)
#
#   File "pandas/_libs/src/inference.pyx", line 1521, in pandas._libs.lib.map_infer
#
#   File "<ipython-input-55-09e963f87256>", line 1, in <lambda>
#     url_list['urls'] = url_list['urls'].map(lambda x: dict(eval(x)))
#
#   File "<string>", line unknown
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
d = url_list['urls'].apply(pd.Series)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-0321bb914f27> in <module>()
# ----> 1 d = url_list['urls'].apply(pd.Series)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2508             else:
#    2509                 values = self.asobject
# -> 2510                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2511
#    2512         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     250             if index is None:
#     251                 if not is_list_like(data):
# ...

# %%
url_list[url_list['urls'].str.contains("pol")]
# Out:
#                       tweetid               userid      screen_name  \
# 2213      1163606689586864128            328935228          OnyxCap
# 2240      1163606689586864128            328935228          OnyxCap
# 2768      1163608502692196353   894433936046272512      MFEnriqueBK
# 13139     1163636307412713472           2459080064  CharlieStGermai
# 15570     1163643299720097793   868248999714734080    peachclafouti
# 15575     1163643300542181376   967828292744040451          916izen
# 15646     1163643299720097793   868248999714734080    peachclafouti
# 15651     1163643300542181376   967828292744040451          916izen
# 17255     1163648847781998592             30050923       DawudWalid
# 20272     1163658226761687042           2887446503  yanggang2020bag
# 21646     1163662371581128705  1012776507826008064  KlasicalLiberal
# 25953     1163674239511252993   826148872053522433  Patrici31864139
# 25955     1163674239511252993   826148872053522433  Patrici31864139
# ...

# %%
df['vax']=''
for i in range(len(df)):
    if df.text[i].find('vax')!= -1:
        df.at[i,'vax']='vax'
len(df[df['vax']=='vax'])
# Out:
# 12

# %%
df['vacc']=''
for i in range(len(df)):
    if df.text[i].find('vacc')!= -1:
        df.at[i,'vacc']='vacc'
len(df[df['vacc']=='vacc'])
# Out:
# 20

# %%
ef=df[(df['vax']=='vax') | (df['vacc']=='vacc')] 
ef.reset_index(drop=True,inplace=True)
len(ef)
# Out:
# 27

# %%
ef.text[25]
# Out:
# 'A major conference in Toronto this April will bring a prominent #antivax activist in as a speaker, along with others who promote misleading, false views (i.e. you can heal cancer through the power of thought). Organizers say they expect 15k ppl to attend https://t.co/dh6nQhruTD'

# %%
for i in range(0,len(df)):
    df.at[i,'datetime']=datetime.strptime(df.at[i,'created_at'], '%a %b %d %H:%M:%S %z %Y').replace(tzinfo=timezone.utc).astimezone(tz=None).strftime('%Y-%m-%d %H:%M:%S')

# %%
df.to_csv('boycott_tweets_date.csv',index=False)

# %%
df.to_csv('boycott_tweets_no_dup.csv',index=False)

# %%
df=pd.read_csv('boycott_tweets_date.csv')

# %%
df
# Out:
#                     tweetid               userid      screen_name  \
# 0       1099096573143728129   893671709819060224         CricMain
# 1       1099097019229093889           2623031687          CWhitam
# 2       1099097413854347264           1530919322       KurtKwzhey
# 3       1099097557056262144   808635704473505792    LiamWat700612
# 4       1099098083718238208             17787675   WarriorWifeMom
# 5       1099098457363615745             17787675   WarriorWifeMom
# 6       1099099771749498880  1098098008800063488     Chevalnuit68
# 7       1099103729062682630            566770459   Chuckwick_Illz
# 8       1099104163273809921  1028298164774875136      coolcrokett
# 9       1099104945565970432           1434528746     IgneousTruth
# 10      1099106592761483264            455264543         countzpr
# 11      1099107319252729858            485413596        dalcahue1
# 12      1099107394016215042            125048530       chiguy8506
# ...

# %%
import pandas as pd
import json
import csv


csv_out = open('botometer_scores.csv', mode='a') #opens csv file
writer = csv.writer(csv_out) #create the csv writer object
# fields=['user_id','screen_name','bot_score']
# writer.writerow(fields) #writes column headers


with open('/Users/ashokdeb/Desktop/boycott/botometer_response/botcott4.json','rb') as f:
    for line in f:
        count=0
        try:
            status = json.loads(line)
#             count +=1
#             if count ==1: break
            bot_score=status['scores']['english']
            id_str=status['user']['id_str']
            screen_name=status['user']['screen_name']
            row=[id_str,screen_name,bot_score]
            writer.writerow(row)
        except:
            continue
csv_out.close()

# %%
status['user']['screen_name']
# Out:
# 'ACHALAGRAWAL'

# %%
bot_scores=pd.read_csv('botometer.csv')

# %%
bot_scores.head()
# Out:
#               user_id  bot_score
# 0  704519938837315584   0.156855
# 1  704519938837315584   0.156855
# 2  704519938837315584   0.145898
# 3  819192609482473473   0.092867
# 4  752883514924597251   0.168473

# %%
# Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns

# matplotlib histogram
# plt.hist(bot_users['scores_uni'], color = 'blue', edgecolor = 'black', bins = 100)

# seaborn histogram
sns.distplot(bot_scores['bot_score'], hist=True, kde=False, 
             bins=20, color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
# plt.title('Histogram for #ivoted')
plt.rcParams['xtick.labelsize']=14
plt.rcParams['ytick.labelsize']=14
plt.xlabel('Bot Score',size=20)
plt.ylabel('User',size=20)
plt.savefig('bot_scores_botometer.png',bbox_inches='tight')
plt.show()

# %%
bot_scores_bh=pd.read_csv('bot_hunter_for_ashok_20190727.csv')

# %%
bot_scores_bh.head()
# Out:
#              status_id             user_id     screen_name  prediction  \
# 0  1154927122554638337  704519938837315584       c74736239        True
# 1  1154997141145673728  819192609482473473       h04994201       False
# 2  1154578136773926913  752883514924597251   HussainSofwan       False
# 3  1155045859215589377  819991315169411072     sactown_mom       False
# 4  1155040216211582977  822004018582913024  ThePoetryMaker       False
#
#    probability
# 0     0.780182
# 1     0.327847
# 2     0.425582
# 3     0.440936
# 4     0.339413

# %%
# Import the libraries
import matplotlib.pyplot as plt
import seaborn as sns

# matplotlib histogram
# plt.hist(bot_users['scores_uni'], color = 'blue', edgecolor = 'black', bins = 100)

# seaborn histogram
sns.distplot(bot_scores_bh['probability'], hist=True, kde=False, 
             bins=20, color = 'blue',
             hist_kws={'edgecolor':'black'})
# Add labels
# plt.title('Histogram for #ivoted')
plt.rcParams['xtick.labelsize']=14
plt.rcParams['ytick.labelsize']=14
plt.xlabel('Bot Score',size=20)
plt.ylabel('User',size=20)
plt.savefig('bot_scores_bothunter.png',bbox_inches='tight')
plt.show()
